# %%
# Importar as bibliotecas
import pandas as pd 
import numpy as np

ENDERECO_DADOS = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'

# Obtendo dados
try:
    df_roubos = pd.read_csv(ENDERECO_DADOS, sep=';', encoding='iso-8859-1')
    # print(df_roubos['munic'].unique())  # testar as impressões
    print(df_roubos['regiao'].unique())  # testar as impressões
    print(df_roubos.head())
except Exception as e:
    print("Erro ao obter dados do ISP: ", e)
# Out:
# ['Capital' 'Baixada Fluminense' 'Interior'
#  'Grande NiterÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â³i'
#  'Grande NiterÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x82Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â³i'
#  'Grande NiterÃ\x83Â\x83Ã\x82Â³i'
#  'Grande NiterÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â³i' 'Grande NiterÃ³i']
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
# 2                 1                0                          0
# 3                 1                0                          0
# 4                 3                0                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
# 2                      0                   637     3
# 3                      0                   473     3
# 4                      0                   147     3
#
# [5 rows x 63 columns]

# %%
# Obtendo dados
try:
    df_roubos = pd.read_csv(ENDERECO_DADOS, sep=';', encoding='iso-8859-1')
    # print(df_roubos['munic'].unique())  # testar as impressões
    # print(df_roubos['regiao'].unique())  # testar as impressões
    print(df_roubos.head())
except Exception as e:
    print("Erro ao obter dados do ISP: ", e)



# Tratando e preparando os dados
try:
    # Delimitando as variáveis
    df_roubos = df_roubos[['cisp', 'regiao', 'munic', 'roubo_veiculo']]
    # print(df_roubos.head())
    # Tratando os erros de acentuação na série região
    correcao_acentuacao = df_roubos['regiao'].str.startswith('Grande Niter', na=False)
    # print(correcao_acentuacao)
    df_roubos.loc[correcao_acentuacao, 'regiao'] = 'Grande Niterói'
    # print(df_roubos['regiao'].unique())

    # Agrupando os dados cisp, região e município
    df_roubos = df_roubos.groupby(['cisp', 'regiao', 'munic']).sum(['roubo_veiculo']).reset_index()

    # Display() é uma função do Jupyter Notebook que permite exibir o DataFrame
    display(df_roubos)
except Exception as e:
    print("Erro no tratamento dos dados: ", e)
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
# 2                 1                0                          0
# 3                 1                0                          0
# 4                 3                0                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
# 2                      0                   637     3
# 3                      0                   473     3
# 4                      0                   147     3
#
# [5 rows x 63 columns]
#      cisp    regiao                 munic  roubo_veiculo
# 0       1   Capital        Rio de Janeiro            565
# 1       4   Capital        Rio de Janeiro           2165
# 2       5   Capital        Rio de Janeiro           1316
# 3       6   Capital        Rio de Janeiro           4516
# 4       7   Capital        Rio de Janeiro           1997
# ..    ...       ...                   ...            ...
# 141   159  Interior  Cachoeiras de Macacu            283
# 142   165  Interior           Mangaratiba            500
# 143   166  Interior        Angra dos Reis            968
# 144   167  Interior                Paraty            105
# 145   168  Interior             Rio Claro             62
#
# [146 rows x 4 columns]

# %%
# Calculando as medidas
try:
    array_roubos = np.array(df_roubos['roubo_veiculo'])
    # print(array_roubos)
    
    media = np.mean(array_roubos)
    mediana = np.median(array_roubos)
    total = np.sum(array_roubos)
    # maximo = np.max(array_roubos)
    # minimo = np.min(array_roubos)

    # Obtendo os Quartis
    q1 = np.quantile(array_roubos, 0.25)
    q3 = np.quantile(array_roubos, 0.75)

    # Printando as medidas
    print('Medidas:')
    print(f'Media: {media:.2f}')
    print(f'Mediana: {mediana}')
    print(f'Total: {total}')

except Exception as e:
    print("Erro ao obter as medidas: ", e)
# Out:
# Medidas:
# Media: 4778.64
# Mediana: 928.0
# Total: 697681

# %%
# Identificando os maiores e menores
try:
    # Gerar um dataframe com os maiores
    # Copy() quando preciar alterar um dataframe já filtrado
    df_maiores =  df_roubos[df_roubos['roubo_veiculo'] > q3].copy()
    df_maiores['flag'] = 'mais' #   cria uma nova coluna
    # print(df_maiores)

    # Gerar um dataframe com os menores
    df_menores = df_roubos[df_roubos['roubo_veiculo'] < q1].copy()
    df_menores['flag'] = 'menos'
    # print(df_menores)

    # Concatenar os dois dataframes
    df_roubos_flags = pd.concat([df_maiores, df_menores], ignore_index=True)

    display(df_roubos_flags)
except Exception as e:
    print("Erro ao identificar os maiores e menores: ", e)
# Out:
#     cisp    regiao                  munic  roubo_veiculo   flag
# 0     17   Capital         Rio de Janeiro           7505   mais
# 1     20   Capital         Rio de Janeiro           8911   mais
# 2     21   Capital         Rio de Janeiro          19279   mais
# 3     22   Capital         Rio de Janeiro          14858   mais
# 4     23   Capital         Rio de Janeiro          10612   mais
# ..   ...       ...                    ...            ...    ...
# 69   155  Interior  São Sebastião do Alto             29  menos
# 70   156  Interior   Santa Maria Madalena             47  menos
# 71   157  Interior      Trajano de Morais             20  menos
# 72   158  Interior             Bom Jardim             21  menos
# 73   168  Interior              Rio Claro             62  menos
#
# [74 rows x 5 columns]

# %%
# Exportando dados csv ou xlsx
try:
    # Testar sem encoding | Impirmir com o encoding utf-8-sig, se precisar do csv fora do BI
    df_roubos_flags.to_csv('roubos_veiculos.csv', index=False)

    # df_roubos_flags.to_excel('roubos_veiculos.xlsx', index=False)

except Exception as e:
    print("Erro ao exportar os dados: ", e)

# %%
#   CRUD - Create, Read, Update, Delete

# %%
# Jogar o dataframe como uma tabela no Banco de dados
from sqlalchemy import create_engine, text

try:
    host = 'localhost'
    user = 'root'
    password = ''
    database = 'bd_roubos_flags'

    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')

    tabela = 'tb_roubo_veiculos'

    #   CREATE
    # Na primeira vez, usar o 'replace' ou 'fail' para criar a tabela
    # A partir da segunda vez, usar o 'append' para adicionar os dados.
    df_roubos_flags.to_sql(tabela, con=engine, if_exists='append', index=False)

except Exception as e:
    print("Erro ao exportar os dados: ", e)

# %%
# READ
# Estrutura with para abrir e fechar o arquivo
with engine.connect() as conexao:
    comando_sql = text("SELECT * FROM tb_roubo_veiculos")
    resultado = conexao.execute(comando_sql)
    for linha in resultado:
        print(linha)
# Out:
# (17, 'Capital', 'Rio de Janeiro', 7505, 'mais')
# (20, 'Capital', 'Rio de Janeiro', 8911, 'mais')
# (21, 'Capital', 'Rio de Janeiro', 19279, 'mais')
# (22, 'Capital', 'Rio de Janeiro', 14858, 'mais')
# (23, 'Capital', 'Rio de Janeiro', 10612, 'mais')
# (24, 'Capital', 'Rio de Janeiro', 11418, 'mais')
# (25, 'Capital', 'Rio de Janeiro', 10792, 'mais')
# (26, 'Capital', 'Rio de Janeiro', 7518, 'mais')
# (27, 'Capital', 'Rio de Janeiro', 26905, 'mais')
# (28, 'Capital', 'Rio de Janeiro', 10771, 'mais')
# (29, 'Capital', 'Rio de Janeiro', 15532, 'mais')
# (30, 'Capital', 'Rio de Janeiro', 12360, 'mais')
# (31, 'Capital', 'Rio de Janeiro', 14428, 'mais')
# (32, 'Capital', 'Rio de Janeiro', 7940, 'mais')
# (33, 'Capital', 'Rio de Janeiro', 17592, 'mais')
# (34, 'Capital', 'Rio de Janeiro', 27001, 'mais')
# (35, 'Capital', 'Rio de Janeiro', 18789, 'mais')
# (37, 'Capital', 'Rio de Janeiro', 7321, 'mais')
# (38, 'Capital', 'Rio de Janeiro', 19332, 'mais')
# (39, 'Capital', 'Rio de Janeiro', 28264, 'mais')
# (40, 'Capital', 'Rio de Janeiro', 18534, 'mais')
# (44, 'Capital', 'Rio de Janeiro', 14285, 'mais')
# (52, 'Baixada Fluminense', 'Nova Iguaçu', 15023, 'mais')
# (53, 'Baixada Fluminense', 'Mesquita', 8190, 'mais')
# (54, 'Baixada Fluminense', 'Belford Roxo', 23967, 'mais')
# (56, 'Baixada Fluminense', 'Nova Iguaçu', 11522, 'mais')
# (57, 'Baixada Fluminense', 'Nilópolis', 12257, 'mais')
# (58, 'Baixada Fluminense', 'Nova Iguaçu', 15657, 'mais')
# (59, 'Baixada Fluminense', 'Duque de Caxias', 36274, 'mais')
# (60, 'Baixada Fluminense', 'Duque de Caxias', 19513, 'mais')
# (62, 'Baixada Fluminense', 'Duque de Caxias', 8667, 'mais')
# (64, 'Baixada Fluminense', 'São João de Meriti', 31386, 'mais')
# (72, 'Grande Niterói', 'São Gonçalo', 13594, 'mais')
# (73, 'Grande Niterói', 'São Gonçalo', 13456, 'mais')
# (74, 'Grande Niterói', 'São Gonçalo', 17461, 'mais')
# (75, 'Grande Niterói', 'São Gonçalo', 9745, 'mais')
# (78, 'Grande Niterói', 'Niterói', 8401, 'mais')
# (11, 'Capital', 'Rio de Janeiro', 16, 'menos')
# (45, 'Capital', 'Rio de Janeiro', 27, 'menos')
# (91, 'Interior', 'Valença', 49, 'menos')
# (92, 'Interior', 'Rio das Flores', 8, 'menos')
# (94, 'Interior', 'Piraí;Pinheiral', 53, 'menos')
# (95, 'Interior', 'Vassouras', 88, 'menos')
# (96, 'Interior', 'Miguel Pereira;Paty dos Alferes', 43, 'menos')
# (97, 'Interior', 'Mendes', 23, 'menos')
# (98, 'Interior', 'Engenheiro Paulo de Frontin', 17, 'menos')
# (100, 'Interior', 'Porto Real;Quatis', 85, 'menos')
# (101, 'Interior', 'Pinheiral', 43, 'menos')
# (104, 'Interior', 'São José do Vale do Rio Preto', 20, 'menos')
# (107, 'Interior', 'Paraíba do Sul', 61, 'menos')
# (111, 'Interior', 'Sumidouro', 39, 'menos')
# (112, 'Interior', 'Carmo', 48, 'menos')
# (132, 'Interior', 'Arraial do Cabo', 54, 'menos')
# (135, 'Interior', 'Itaocara', 24, 'menos')
# (136, 'Interior', 'Santo Antônio de Pádua;Aperibé', 63, 'menos')
# (137, 'Interior', 'Miracema', 6, 'menos')
# (138, 'Interior', 'Laje do Muriaé', 2, 'menos')
# (139, 'Interior', 'Porciúncula', 7, 'menos')
# (140, 'Interior', 'Natividade;Varre-Sai', 7, 'menos')
# (141, 'Interior', 'São Fidélis', 77, 'menos')
# (142, 'Interior', 'Cambuci', 9, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá', 63, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá;Cardoso Moreira;Italva', 25, 'menos')
# (144, 'Interior', 'Bom Jesus de Itabapoana', 19, 'menos')
# (146, 'Interior', 'Campos dos Goytacazes;São Francisco de Itabapoana', 31, 'menos')
# (148, 'Interior', 'Cardoso Moreira;Italva', 26, 'menos')
# (152, 'Interior', 'Duas Barras', 13, 'menos')
# (153, 'Interior', 'Cantagalo', 58, 'menos')
# (154, 'Interior', 'Cordeiro;Macuco', 21, 'menos')
# (155, 'Interior', 'São Sebastião do Alto', 29, 'menos')
# (156, 'Interior', 'Santa Maria Madalena', 47, 'menos')
# (157, 'Interior', 'Trajano de Morais', 20, 'menos')
# (158, 'Interior', 'Bom Jardim', 21, 'menos')
# (168, 'Interior', 'Rio Claro', 62, 'menos')
# (17, 'Capital', 'Rio de Janeiro', 7505, 'mais')
# (20, 'Capital', 'Rio de Janeiro', 8911, 'mais')
# (21, 'Capital', 'Rio de Janeiro', 19279, 'mais')
# (22, 'Capital', 'Rio de Janeiro', 14858, 'mais')
# (23, 'Capital', 'Rio de Janeiro', 10612, 'mais')
# (24, 'Capital', 'Rio de Janeiro', 11418, 'mais')
# (25, 'Capital', 'Rio de Janeiro', 10792, 'mais')
# (26, 'Capital', 'Rio de Janeiro', 7518, 'mais')
# (27, 'Capital', 'Rio de Janeiro', 26905, 'mais')
# (28, 'Capital', 'Rio de Janeiro', 10771, 'mais')
# (29, 'Capital', 'Rio de Janeiro', 15532, 'mais')
# (30, 'Capital', 'Rio de Janeiro', 12360, 'mais')
# (31, 'Capital', 'Rio de Janeiro', 14428, 'mais')
# (32, 'Capital', 'Rio de Janeiro', 7940, 'mais')
# (33, 'Capital', 'Rio de Janeiro', 17592, 'mais')
# (34, 'Capital', 'Rio de Janeiro', 27001, 'mais')
# (35, 'Capital', 'Rio de Janeiro', 18789, 'mais')
# (37, 'Capital', 'Rio de Janeiro', 7321, 'mais')
# (38, 'Capital', 'Rio de Janeiro', 19332, 'mais')
# (39, 'Capital', 'Rio de Janeiro', 28264, 'mais')
# (40, 'Capital', 'Rio de Janeiro', 18534, 'mais')
# (44, 'Capital', 'Rio de Janeiro', 14285, 'mais')
# (52, 'Baixada Fluminense', 'Nova Iguaçu', 15023, 'mais')
# (53, 'Baixada Fluminense', 'Mesquita', 8190, 'mais')
# (54, 'Baixada Fluminense', 'Belford Roxo', 23967, 'mais')
# (56, 'Baixada Fluminense', 'Nova Iguaçu', 11522, 'mais')
# (57, 'Baixada Fluminense', 'Nilópolis', 12257, 'mais')
# (58, 'Baixada Fluminense', 'Nova Iguaçu', 15657, 'mais')
# (59, 'Baixada Fluminense', 'Duque de Caxias', 36274, 'mais')
# (60, 'Baixada Fluminense', 'Duque de Caxias', 19513, 'mais')
# (62, 'Baixada Fluminense', 'Duque de Caxias', 8667, 'mais')
# (64, 'Baixada Fluminense', 'São João de Meriti', 31386, 'mais')
# (72, 'Grande Niterói', 'São Gonçalo', 13594, 'mais')
# (73, 'Grande Niterói', 'São Gonçalo', 13456, 'mais')
# (74, 'Grande Niterói', 'São Gonçalo', 17461, 'mais')
# (75, 'Grande Niterói', 'São Gonçalo', 9745, 'mais')
# (78, 'Grande Niterói', 'Niterói', 8401, 'mais')
# (11, 'Capital', 'Rio de Janeiro', 16, 'menos')
# (45, 'Capital', 'Rio de Janeiro', 27, 'menos')
# (91, 'Interior', 'Valença', 49, 'menos')
# (92, 'Interior', 'Rio das Flores', 8, 'menos')
# (94, 'Interior', 'Piraí;Pinheiral', 53, 'menos')
# (95, 'Interior', 'Vassouras', 88, 'menos')
# (96, 'Interior', 'Miguel Pereira;Paty dos Alferes', 43, 'menos')
# (97, 'Interior', 'Mendes', 23, 'menos')
# (98, 'Interior', 'Engenheiro Paulo de Frontin', 17, 'menos')
# (100, 'Interior', 'Porto Real;Quatis', 85, 'menos')
# (101, 'Interior', 'Pinheiral', 43, 'menos')
# (104, 'Interior', 'São José do Vale do Rio Preto', 20, 'menos')
# (107, 'Interior', 'Paraíba do Sul', 61, 'menos')
# (111, 'Interior', 'Sumidouro', 39, 'menos')
# (112, 'Interior', 'Carmo', 48, 'menos')
# (132, 'Interior', 'Arraial do Cabo', 54, 'menos')
# (135, 'Interior', 'Itaocara', 24, 'menos')
# (136, 'Interior', 'Santo Antônio de Pádua;Aperibé', 63, 'menos')
# (137, 'Interior', 'Miracema', 6, 'menos')
# (138, 'Interior', 'Laje do Muriaé', 2, 'menos')
# (139, 'Interior', 'Porciúncula', 7, 'menos')
# (140, 'Interior', 'Natividade;Varre-Sai', 7, 'menos')
# (141, 'Interior', 'São Fidélis', 77, 'menos')
# (142, 'Interior', 'Cambuci', 9, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá', 63, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá;Cardoso Moreira;Italva', 25, 'menos')
# (144, 'Interior', 'Bom Jesus de Itabapoana', 19, 'menos')
# (146, 'Interior', 'Campos dos Goytacazes;São Francisco de Itabapoana', 31, 'menos')
# (148, 'Interior', 'Cardoso Moreira;Italva', 26, 'menos')
# (152, 'Interior', 'Duas Barras', 13, 'menos')
# (153, 'Interior', 'Cantagalo', 58, 'menos')
# (154, 'Interior', 'Cordeiro;Macuco', 21, 'menos')
# (155, 'Interior', 'São Sebastião do Alto', 29, 'menos')
# (156, 'Interior', 'Santa Maria Madalena', 47, 'menos')
# (157, 'Interior', 'Trajano de Morais', 20, 'menos')
# (158, 'Interior', 'Bom Jardim', 21, 'menos')
# (168, 'Interior', 'Rio Claro', 62, 'menos')
# (76, 'Grande Niterói', 'Niterói', 20, 'menos')
# (17, 'Capital', 'Rio de Janeiro', 7505, 'mais')
# (20, 'Capital', 'Rio de Janeiro', 8911, 'mais')
# (21, 'Capital', 'Rio de Janeiro', 19279, 'mais')
# (22, 'Capital', 'Rio de Janeiro', 14858, 'mais')
# (23, 'Capital', 'Rio de Janeiro', 10612, 'mais')
# (24, 'Capital', 'Rio de Janeiro', 11418, 'mais')
# (25, 'Capital', 'Rio de Janeiro', 10792, 'mais')
# (26, 'Capital', 'Rio de Janeiro', 7518, 'mais')
# (27, 'Capital', 'Rio de Janeiro', 26905, 'mais')
# (28, 'Capital', 'Rio de Janeiro', 10771, 'mais')
# (29, 'Capital', 'Rio de Janeiro', 15532, 'mais')
# (30, 'Capital', 'Rio de Janeiro', 12360, 'mais')
# (31, 'Capital', 'Rio de Janeiro', 14428, 'mais')
# (32, 'Capital', 'Rio de Janeiro', 7940, 'mais')
# (33, 'Capital', 'Rio de Janeiro', 17592, 'mais')
# (34, 'Capital', 'Rio de Janeiro', 27001, 'mais')
# (35, 'Capital', 'Rio de Janeiro', 18789, 'mais')
# (37, 'Capital', 'Rio de Janeiro', 7321, 'mais')
# (38, 'Capital', 'Rio de Janeiro', 19332, 'mais')
# (39, 'Capital', 'Rio de Janeiro', 28264, 'mais')
# (40, 'Capital', 'Rio de Janeiro', 18534, 'mais')
# (44, 'Capital', 'Rio de Janeiro', 14285, 'mais')
# (52, 'Baixada Fluminense', 'Nova Iguaçu', 15023, 'mais')
# (53, 'Baixada Fluminense', 'Mesquita', 8190, 'mais')
# (54, 'Baixada Fluminense', 'Belford Roxo', 23967, 'mais')
# (56, 'Baixada Fluminense', 'Nova Iguaçu', 11522, 'mais')
# (57, 'Baixada Fluminense', 'Nilópolis', 12257, 'mais')
# (58, 'Baixada Fluminense', 'Nova Iguaçu', 15657, 'mais')
# (59, 'Baixada Fluminense', 'Duque de Caxias', 36274, 'mais')
# (60, 'Baixada Fluminense', 'Duque de Caxias', 19513, 'mais')
# (62, 'Baixada Fluminense', 'Duque de Caxias', 8667, 'mais')
# (64, 'Baixada Fluminense', 'São João de Meriti', 31386, 'mais')
# (72, 'Grande Niterói', 'São Gonçalo', 13594, 'mais')
# (73, 'Grande Niterói', 'São Gonçalo', 13456, 'mais')
# (74, 'Grande Niterói', 'São Gonçalo', 17461, 'mais')
# (75, 'Grande Niterói', 'São Gonçalo', 9745, 'mais')
# (78, 'Grande Niterói', 'Niterói', 8401, 'mais')
# (11, 'Capital', 'Rio de Janeiro', 16, 'menos')
# (45, 'Capital', 'Rio de Janeiro', 27, 'menos')
# (91, 'Interior', 'Valença', 49, 'menos')
# (92, 'Interior', 'Rio das Flores', 8, 'menos')
# (94, 'Interior', 'Piraí;Pinheiral', 53, 'menos')
# (95, 'Interior', 'Vassouras', 88, 'menos')
# (96, 'Interior', 'Miguel Pereira;Paty dos Alferes', 43, 'menos')
# (97, 'Interior', 'Mendes', 23, 'menos')
# (98, 'Interior', 'Engenheiro Paulo de Frontin', 17, 'menos')
# (100, 'Interior', 'Porto Real;Quatis', 85, 'menos')
# (101, 'Interior', 'Pinheiral', 43, 'menos')
# (104, 'Interior', 'São José do Vale do Rio Preto', 20, 'menos')
# (107, 'Interior', 'Paraíba do Sul', 61, 'menos')
# (111, 'Interior', 'Sumidouro', 39, 'menos')
# (112, 'Interior', 'Carmo', 48, 'menos')
# (132, 'Interior', 'Arraial do Cabo', 54, 'menos')
# (135, 'Interior', 'Itaocara', 24, 'menos')
# (136, 'Interior', 'Santo Antônio de Pádua;Aperibé', 63, 'menos')
# (137, 'Interior', 'Miracema', 6, 'menos')
# (138, 'Interior', 'Laje do Muriaé', 2, 'menos')
# (139, 'Interior', 'Porciúncula', 7, 'menos')
# (140, 'Interior', 'Natividade;Varre-Sai', 7, 'menos')
# (141, 'Interior', 'São Fidélis', 77, 'menos')
# (142, 'Interior', 'Cambuci', 9, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá', 63, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá;Cardoso Moreira;Italva', 25, 'menos')
# (144, 'Interior', 'Bom Jesus de Itabapoana', 19, 'menos')
# (146, 'Interior', 'Campos dos Goytacazes;São Francisco de Itabapoana', 31, 'menos')
# (148, 'Interior', 'Cardoso Moreira;Italva', 26, 'menos')
# (152, 'Interior', 'Duas Barras', 13, 'menos')
# (153, 'Interior', 'Cantagalo', 58, 'menos')
# (154, 'Interior', 'Cordeiro;Macuco', 21, 'menos')
# (155, 'Interior', 'São Sebastião do Alto', 29, 'menos')
# (156, 'Interior', 'Santa Maria Madalena', 47, 'menos')
# (157, 'Interior', 'Trajano de Morais', 20, 'menos')
# (158, 'Interior', 'Bom Jardim', 21, 'menos')
# (168, 'Interior', 'Rio Claro', 62, 'menos')
# (76, 'Grande Niterói', 'Niterói', 20, 'menos')
# (76, 'Grande Niterói', 'São Gonçalo', 100, 'menos')
# (17, 'Capital', 'Rio de Janeiro', 7505, 'mais')
# (20, 'Capital', 'Rio de Janeiro', 8911, 'mais')
# (21, 'Capital', 'Rio de Janeiro', 19279, 'mais')
# (22, 'Capital', 'Rio de Janeiro', 14858, 'mais')
# (23, 'Capital', 'Rio de Janeiro', 10612, 'mais')
# (24, 'Capital', 'Rio de Janeiro', 11418, 'mais')
# (25, 'Capital', 'Rio de Janeiro', 10792, 'mais')
# (26, 'Capital', 'Rio de Janeiro', 7518, 'mais')
# (27, 'Capital', 'Rio de Janeiro', 26905, 'mais')
# (28, 'Capital', 'Rio de Janeiro', 10771, 'mais')
# (29, 'Capital', 'Rio de Janeiro', 15532, 'mais')
# (30, 'Capital', 'Rio de Janeiro', 12360, 'mais')
# (31, 'Capital', 'Rio de Janeiro', 14428, 'mais')
# (32, 'Capital', 'Rio de Janeiro', 7940, 'mais')
# (33, 'Capital', 'Rio de Janeiro', 17592, 'mais')
# (34, 'Capital', 'Rio de Janeiro', 27001, 'mais')
# (35, 'Capital', 'Rio de Janeiro', 18789, 'mais')
# (37, 'Capital', 'Rio de Janeiro', 7321, 'mais')
# (38, 'Capital', 'Rio de Janeiro', 19332, 'mais')
# (39, 'Capital', 'Rio de Janeiro', 28264, 'mais')
# (40, 'Capital', 'Rio de Janeiro', 18534, 'mais')
# (44, 'Capital', 'Rio de Janeiro', 14285, 'mais')
# (52, 'Baixada Fluminense', 'Nova Iguaçu', 15023, 'mais')
# (53, 'Baixada Fluminense', 'Mesquita', 8190, 'mais')
# (54, 'Baixada Fluminense', 'Belford Roxo', 23967, 'mais')
# (56, 'Baixada Fluminense', 'Nova Iguaçu', 11522, 'mais')
# (57, 'Baixada Fluminense', 'Nilópolis', 12257, 'mais')
# (58, 'Baixada Fluminense', 'Nova Iguaçu', 15657, 'mais')
# (59, 'Baixada Fluminense', 'Duque de Caxias', 36274, 'mais')
# (60, 'Baixada Fluminense', 'Duque de Caxias', 19513, 'mais')
# (62, 'Baixada Fluminense', 'Duque de Caxias', 8667, 'mais')
# (64, 'Baixada Fluminense', 'São João de Meriti', 31386, 'mais')
# (72, 'Grande Niterói', 'São Gonçalo', 13594, 'mais')
# (73, 'Grande Niterói', 'São Gonçalo', 13456, 'mais')
# (74, 'Grande Niterói', 'São Gonçalo', 17461, 'mais')
# (75, 'Grande Niterói', 'São Gonçalo', 9745, 'mais')
# (78, 'Grande Niterói', 'Niterói', 8401, 'mais')
# (11, 'Capital', 'Rio de Janeiro', 16, 'menos')
# (45, 'Capital', 'Rio de Janeiro', 27, 'menos')
# (91, 'Interior', 'Valença', 49, 'menos')
# (92, 'Interior', 'Rio das Flores', 8, 'menos')
# (94, 'Interior', 'Piraí;Pinheiral', 53, 'menos')
# (95, 'Interior', 'Vassouras', 88, 'menos')
# (96, 'Interior', 'Miguel Pereira;Paty dos Alferes', 43, 'menos')
# (97, 'Interior', 'Mendes', 23, 'menos')
# (98, 'Interior', 'Engenheiro Paulo de Frontin', 17, 'menos')
# (100, 'Interior', 'Porto Real;Quatis', 85, 'menos')
# (101, 'Interior', 'Pinheiral', 43, 'menos')
# (104, 'Interior', 'São José do Vale do Rio Preto', 20, 'menos')
# (107, 'Interior', 'Paraíba do Sul', 61, 'menos')
# (111, 'Interior', 'Sumidouro', 39, 'menos')
# (112, 'Interior', 'Carmo', 48, 'menos')
# (132, 'Interior', 'Arraial do Cabo', 54, 'menos')
# (135, 'Interior', 'Itaocara', 24, 'menos')
# (136, 'Interior', 'Santo Antônio de Pádua;Aperibé', 63, 'menos')
# (137, 'Interior', 'Miracema', 6, 'menos')
# (138, 'Interior', 'Laje do Muriaé', 2, 'menos')
# (139, 'Interior', 'Porciúncula', 7, 'menos')
# (140, 'Interior', 'Natividade;Varre-Sai', 7, 'menos')
# (141, 'Interior', 'São Fidélis', 77, 'menos')
# (142, 'Interior', 'Cambuci', 9, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá', 63, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá;Cardoso Moreira;Italva', 25, 'menos')
# (144, 'Interior', 'Bom Jesus de Itabapoana', 19, 'menos')
# (146, 'Interior', 'Campos dos Goytacazes;São Francisco de Itabapoana', 31, 'menos')
# (148, 'Interior', 'Cardoso Moreira;Italva', 26, 'menos')
# (152, 'Interior', 'Duas Barras', 13, 'menos')
# (153, 'Interior', 'Cantagalo', 58, 'menos')
# (154, 'Interior', 'Cordeiro;Macuco', 21, 'menos')
# (155, 'Interior', 'São Sebastião do Alto', 29, 'menos')
# (156, 'Interior', 'Santa Maria Madalena', 47, 'menos')
# (157, 'Interior', 'Trajano de Morais', 20, 'menos')
# (158, 'Interior', 'Bom Jardim', 21, 'menos')
# (168, 'Interior', 'Rio Claro', 62, 'menos')
# (76, 'Grande Niterói', 'Niterói', 20, 'menos')
# (76, 'Grande Niterói', 'São Gonçalo', 100, 'menos')
# (17, 'Capital', 'Rio de Janeiro', 7505, 'mais')
# (20, 'Capital', 'Rio de Janeiro', 8911, 'mais')
# (21, 'Capital', 'Rio de Janeiro', 19279, 'mais')
# (22, 'Capital', 'Rio de Janeiro', 14858, 'mais')
# (23, 'Capital', 'Rio de Janeiro', 10612, 'mais')
# (24, 'Capital', 'Rio de Janeiro', 11418, 'mais')
# (25, 'Capital', 'Rio de Janeiro', 10792, 'mais')
# (26, 'Capital', 'Rio de Janeiro', 7518, 'mais')
# (27, 'Capital', 'Rio de Janeiro', 26905, 'mais')
# (28, 'Capital', 'Rio de Janeiro', 10771, 'mais')
# (29, 'Capital', 'Rio de Janeiro', 15532, 'mais')
# (30, 'Capital', 'Rio de Janeiro', 12360, 'mais')
# (31, 'Capital', 'Rio de Janeiro', 14428, 'mais')
# (32, 'Capital', 'Rio de Janeiro', 7940, 'mais')
# (33, 'Capital', 'Rio de Janeiro', 17592, 'mais')
# (34, 'Capital', 'Rio de Janeiro', 27001, 'mais')
# (35, 'Capital', 'Rio de Janeiro', 18789, 'mais')
# (37, 'Capital', 'Rio de Janeiro', 7321, 'mais')
# (38, 'Capital', 'Rio de Janeiro', 19332, 'mais')
# (39, 'Capital', 'Rio de Janeiro', 28264, 'mais')
# (40, 'Capital', 'Rio de Janeiro', 18534, 'mais')
# (44, 'Capital', 'Rio de Janeiro', 14285, 'mais')
# (52, 'Baixada Fluminense', 'Nova Iguaçu', 15023, 'mais')
# (53, 'Baixada Fluminense', 'Mesquita', 8190, 'mais')
# (54, 'Baixada Fluminense', 'Belford Roxo', 23967, 'mais')
# (56, 'Baixada Fluminense', 'Nova Iguaçu', 11522, 'mais')
# (57, 'Baixada Fluminense', 'Nilópolis', 12257, 'mais')
# (58, 'Baixada Fluminense', 'Nova Iguaçu', 15657, 'mais')
# (59, 'Baixada Fluminense', 'Duque de Caxias', 36274, 'mais')
# (60, 'Baixada Fluminense', 'Duque de Caxias', 19513, 'mais')
# (62, 'Baixada Fluminense', 'Duque de Caxias', 8667, 'mais')
# (64, 'Baixada Fluminense', 'São João de Meriti', 31386, 'mais')
# (72, 'Grande Niterói', 'São Gonçalo', 13594, 'mais')
# (73, 'Grande Niterói', 'São Gonçalo', 13456, 'mais')
# (74, 'Grande Niterói', 'São Gonçalo', 17461, 'mais')
# (75, 'Grande Niterói', 'São Gonçalo', 9745, 'mais')
# (78, 'Grande Niterói', 'Niterói', 8401, 'mais')
# (11, 'Capital', 'Rio de Janeiro', 16, 'menos')
# (45, 'Capital', 'Rio de Janeiro', 27, 'menos')
# (91, 'Interior', 'Valença', 49, 'menos')
# (92, 'Interior', 'Rio das Flores', 8, 'menos')
# (94, 'Interior', 'Piraí;Pinheiral', 53, 'menos')
# (95, 'Interior', 'Vassouras', 88, 'menos')
# (96, 'Interior', 'Miguel Pereira;Paty dos Alferes', 43, 'menos')
# (97, 'Interior', 'Mendes', 23, 'menos')
# (98, 'Interior', 'Engenheiro Paulo de Frontin', 17, 'menos')
# (100, 'Interior', 'Porto Real;Quatis', 85, 'menos')
# (101, 'Interior', 'Pinheiral', 43, 'menos')
# (104, 'Interior', 'São José do Vale do Rio Preto', 20, 'menos')
# (107, 'Interior', 'Paraíba do Sul', 61, 'menos')
# (111, 'Interior', 'Sumidouro', 39, 'menos')
# (112, 'Interior', 'Carmo', 48, 'menos')
# (132, 'Interior', 'Arraial do Cabo', 54, 'menos')
# (135, 'Interior', 'Itaocara', 24, 'menos')
# (136, 'Interior', 'Santo Antônio de Pádua;Aperibé', 63, 'menos')
# (137, 'Interior', 'Miracema', 6, 'menos')
# (138, 'Interior', 'Laje do Muriaé', 2, 'menos')
# (139, 'Interior', 'Porciúncula', 7, 'menos')
# (140, 'Interior', 'Natividade;Varre-Sai', 7, 'menos')
# (141, 'Interior', 'São Fidélis', 77, 'menos')
# (142, 'Interior', 'Cambuci', 9, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá', 63, 'menos')
# (143, 'Interior', 'Itaperuna;São José de Ubá;Cardoso Moreira;Italva', 25, 'menos')
# (144, 'Interior', 'Bom Jesus de Itabapoana', 19, 'menos')
# (146, 'Interior', 'Campos dos Goytacazes;São Francisco de Itabapoana', 31, 'menos')
# (148, 'Interior', 'Cardoso Moreira;Italva', 26, 'menos')
# (152, 'Interior', 'Duas Barras', 13, 'menos')
# (153, 'Interior', 'Cantagalo', 58, 'menos')
# (154, 'Interior', 'Cordeiro;Macuco', 21, 'menos')
# (155, 'Interior', 'São Sebastião do Alto', 29, 'menos')
# (156, 'Interior', 'Santa Maria Madalena', 47, 'menos')
# (157, 'Interior', 'Trajano de Morais', 20, 'menos')
# (158, 'Interior', 'Bom Jardim', 21, 'menos')
# (168, 'Interior', 'Rio Claro', 62, 'menos')

# %%
# CREATE
with engine.connect() as conexao:
    comando_sql = text(
        """
            INSERT INTO tb_roubo_veiculos (cisp, regiao, munic, roubo_veiculo, flag)
            VALUES (171, 'Grande Niterói', 'São Gonçalo', 500, 'mais')
        """
    )
    
    conexao.execute(comando_sql)

    conexao.commit()

# %%
# CREATE
# Estrutura with para abrir e fechar o arquivo
with engine.connect() as conexao:
    comando_sql = text(
    # Inserir a 69 também ('Niterói', 'Grande Niterói', 'mais')
        """
        INSERT INTO tb_roubo_veiculos (cisp, regiao, munic, roubo_veiculo, flag)
        VALUES (:cisp, :regiao, :munic, :roubo_veiculo, :flag)
        """
    )
    
    conexao.execute(comando_sql, {
        'cisp': 76,
        'regiao': 'Grande Niterói',
        'munic': 'São Gonçalo',
        'roubo_veiculo': 100,
        'flag': 'menos'
    })

    conexao.commit()

# %%
# UPDATE
# Onde a cisp é 171, passa a ser 76,
# e atualizando para São Gonçalo, flag 'menos', roubo 20 etc
with engine.connect() as conexao:

    regiao = 'Grande Niterói'
    munic = 'Niterói'
    roubo_veiculo = 20
    flag = 'menos'
    cisp_nova = 76
    cisp_atual = 171

    comando_sql = text(
        """
            UPDATE tb_roubo_veiculos
            SET regiao = :regiao,
                cisp = :cisp_nova,
                munic = :munic,
                roubo_veiculo = :roubo_veiculo,
                flag = :flag
            WHERE cisp = :cisp_atual
        """
    )
#   DADOS A SEREM ATUALIZADOS
    conexao.execute(comando_sql, {
        'regiao': regiao,
        'cisp_nova': cisp_nova,
        'munic': munic,
        'roubo_veiculo': roubo_veiculo,
        'flag': flag,
        'cisp_atual': cisp_atual
        }
    )
    
    conexao.commit()

# %%
# DELETE
with engine.connect() as conexao:

    comando_sql = text(
        """
            DELETE FROM tb_roubo_veiculos
            WHERE cisp = :cisp
        """
    )

    conexao.execute(comando_sql, {
        'cisp': 69
        }
    )

    conexao.commit()
